# %%
# Install required libraries
# !pip install opendatasets --upgrade --quiet
# !pip install kaggle --quiet

# Import libraries for downloading the dataset
import opendatasets as od
import os
import random
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.models import Model
import tensorflow as tf
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time

# Download dataset from Kaggle
dataset_url = 'https://www.kaggle.com/datasets/punfake/resisc45'
od.download(dataset_url)

# Set the path to the image folder
data_path = 'resisc45/NWPU-RESISC45'

# Initialize image data and labels
image_data = []
labels = []

# Load the image dataset
for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".jpg"):
            # Read the image
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (32, 32))  # Resize
            image = img_to_array(image)
            image_data.append(image)

            # Use the folder name as the label
            label = root.split(os.path.sep)[-1]
            labels.append(label)

# Convert to numpy arrays and normalize the images
image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

# Binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)

print(f'Training samples: {len(x_train)}, Testing samples: {len(x_test)}')

# Define the teacher model (more layers)
def teacher_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Define the student model (fewer layers)
def student_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (32, 32, 3)  # Updated input shape
num_classes = len(lb.classes_)

# Build teacher and student models
teacher = teacher_model(input_shape, num_classes)
student = student_model(input_shape, num_classes)

# Define a learning rate scheduler function
def lr_scheduler(epoch, lr):
    return float(lr * tf.math.exp(-0.1)) if epoch >= 10 else float(lr)

# Compile and train the teacher model
teacher.compile(optimizer=SGD(learning_rate=1e-2, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
teacher.fit(x_train, y_train, batch_size=32, epochs=8, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Precompute teacher's predictions for distillation
teacher_preds = teacher.predict(x_train)

# Define distillation loss function
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true = tf.keras.activations.softmax(y_true / temperature)
    y_pred = tf.keras.activations.softmax(y_pred / temperature)
    teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return alpha * soft_loss + (1. - alpha) * hard_loss
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: akshayanand2002
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/punfake/resisc45
# Downloading resisc45.zip to ./resisc45
# 100%|██████████| 407M/407M [00:07<00:00, 57.2MB/s]
# Training samples: 25200, Testing samples: 6300
# Epoch 1/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 298s 377ms/step - accuracy: 0.0491 - loss: 3.6701 - val_accuracy: 0.1213 - val_loss: 3.2301 - learning_rate: 0.0100
# Epoch 2/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 320s 374ms/step - accuracy: 0.1688 - loss: 3.0365 - val_accuracy: 0.2321 - val_loss: 2.7754 - learning_rate: 0.0100
# Epoch 3/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 325s 379ms/step - accuracy: 0.2767 - loss: 2.5519 - val_accuracy: 0.3392 - val_loss: 2.3297 - learning_rate: 0.0100
# Epoch 4/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 295s 375ms/step - accuracy: 0.3504 - loss: 2.2666 - val_accuracy: 0.4414 - val_loss: 1.9699 - learning_rate: 0.0100
# Epoch 5/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 327s 381ms/step - accuracy: 0.4247 - loss: 1.9660 - val_accuracy: 0.4549 - val_loss: 1.8732 - learning_rate: 0.0100
# Epoch 6/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 317s 375ms/step - accuracy: 0.4919 - loss: 1.7301 - val_accuracy: 0.5298 - val_loss: 1.5980 - learning_rate: 0.0100
# Epoch 7/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 323s 375ms/step - accuracy: 0.5507 - loss: 1.5137 - val_accuracy: 0.5671 - val_loss: 1.4791 - learning_rate: 0.0100
# Epoch 8/8
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 322s 375ms/step - accuracy: 0.6056 - loss: 1.3059 - val_accuracy: 0.5819 - val_loss: 1.4294 - learning_rate: 0.0100
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 73s 92ms/step

# %%
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
# Out:
# Teacher test accuracy: 58.19%

# %%
student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds), metrics=['accuracy'])
student.fit(x_train, y_train, batch_size=32, epochs=10, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])
# Out:
# Epoch 1/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 95s 117ms/step - accuracy: 0.0522 - loss: 3.8066 - val_accuracy: 0.1948 - val_loss: 3.8065 - learning_rate: 0.0010
# Epoch 2/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 72s 91ms/step - accuracy: 0.1962 - loss: 3.8065 - val_accuracy: 0.3110 - val_loss: 3.8064 - learning_rate: 0.0010
# Epoch 3/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 70s 88ms/step - accuracy: 0.2844 - loss: 3.8065 - val_accuracy: 0.3911 - val_loss: 3.8064 - learning_rate: 0.0010
# Epoch 4/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.3562 - loss: 3.8064 - val_accuracy: 0.4249 - val_loss: 3.8063 - learning_rate: 0.0010
# Epoch 5/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.4080 - loss: 3.8063 - val_accuracy: 0.4570 - val_loss: 3.8063 - learning_rate: 0.0010
# Epoch 6/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 82s 89ms/step - accuracy: 0.4443 - loss: 3.8063 - val_accuracy: 0.4794 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 7/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.4801 - loss: 3.8062 - val_accuracy: 0.5056 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 8/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 78s 87ms/step - accuracy: 0.5218 - loss: 3.8062 - val_accuracy: 0.5403 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 9/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.5413 - loss: 3.8062 - val_accuracy: 0.5305 - val_loss: 3.8062 - learning_rate: 0.0010
# Epoch 10/10
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.5717 - loss: 3.8061 - val_accuracy: 0.5516 - val_loss: 3.8062 - learning_rate: 0.0010

# %%
# Evaluate models
#teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
student_score = student.evaluate(x_test, y_test, verbose=0)
#print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Student test accuracy: 55.16%

# %%
# Evaluate the teacher model
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)

print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')

# Generate predictions from the teacher model
teacher_preds_probs = teacher.predict(x_test)
teacher_preds = np.argmax(teacher_preds_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Print the classification report for the teacher model
print("=== Teacher Model Classification Report ===")
print(classification_report(y_true, teacher_preds, target_names=lb.classes_))
# Out:
# Teacher test accuracy: 58.19%
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step
# === Teacher Model Classification Report ===
#                        precision    recall  f1-score   support
#
#              airplane       0.76      0.60      0.67       142
#               airport       0.35      0.50      0.41       141
#      baseball_diamond       0.74      0.38      0.50       142
#      basketball_court       0.32      0.52      0.40       130
#                 beach       0.69      0.65      0.67       127
#                bridge       0.60      0.80      0.69       137
#             chaparral       0.97      0.74      0.84       138
#                church       0.66      0.28      0.39       135
#     circular_farmland       0.62      0.79      0.70       119
#                 cloud       0.74      0.79      0.77       137
#       commercial_area       0.33      0.57      0.42       141
#     dense_residential       0.55      0.78      0.64       138
#                desert       0.88      0.83      0.85       127
#                forest       0.74      0.89      0.81       139
#               freeway       0.70      0.30      0.42       147
#           golf_course       0.53      0.77      0.63       142
#    ground_track_field       0.44      0.64      0.52       140
#                harbor       0.83      0.58      0.68       147
#       industrial_area       0.66      0.57      0.61       141
#          intersection       0.72      0.51      0.60       154
#                island       0.81      0.87      0.84       138
#                  lake       0.80      0.86      0.83       122
#                meadow       0.83      0.88      0.86       151
#    medium_residential       0.38      0.44      0.41       115
#      mobile_home_park       0.74      0.50      0.60       151
#              mountain       0.44      0.57      0.49       138
#              overpass       0.64      0.43      0.52       129
#                palace       0.52      0.18      0.27       150
#           parking_lot       0.70      0.53      0.60       138
#               railway       0.32      0.54      0.41       144
#       railway_station       0.21      0.52      0.30       124
#  rectangular_farmland       0.62      0.32      0.43       124
#                 river       0.65      0.62      0.64       137
#            roundabout       0.52      0.25      0.33       142
#                runway       0.58      0.61      0.59       146
#               sea_ice       0.76      0.84      0.80       171
#                  ship       0.56      0.53      0.54       158
#              snowberg       0.81      0.64      0.72       135
#    sparse_residential       0.78      0.67      0.72       136
#               stadium       0.86      0.66      0.75       147
#          storage_tank       0.67      0.37      0.48       134
#          tennis_court       0.44      0.35      0.39       144
#               terrace       0.51      0.62      0.56       157
# thermal_power_station       0.45      0.45      0.45       153
#               wetland       0.56      0.45      0.50       152
#
#              accuracy                           0.58      6300
#             macro avg       0.62      0.58      0.58      6300
#          weighted avg       0.62      0.58      0.58      6300

# %%
#alpha_values = [0.01, 0.1, 0.2, 0.3, 0.4]
alpha_values = [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
f1_scores = []
accuracies = []
precisions = []
recalls = []
inference_times = []

teacher_preds = teacher.predict(x_train)

# Function to evaluate F1-score, accuracy, precision, recall, and inference time for a given model and alpha
def evaluate_student_with_alpha(alpha):
    # Redefine distillation loss function with current alpha
    def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=alpha):
        teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
        y_true = tf.keras.activations.softmax(y_true / temperature)
        y_pred = tf.keras.activations.softmax(y_pred / temperature)
        teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
        soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
        hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return alpha * soft_loss + (1. - alpha) * hard_loss

    # Compile the student model with the new distillation loss
    student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                    loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds),
                    metrics=['accuracy'])

    # Train the student model
    student.fit(x_train, y_train, batch_size=32, epochs=10, validation_data=(x_test, y_test),
                callbacks=[LearningRateScheduler(lr_scheduler)], verbose=0)

    # Predict and evaluate
    start_time = time.time()
    y_pred_probs = student.predict(x_test)
    inference_time = time.time() - start_time
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate and store F1-score, accuracy, precision, recall, and inference time
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')

    # Append the results
    f1_scores.append(f1)
    accuracies.append(acc)
    precisions.append(precision)
    recalls.append(recall)
    inference_times.append(inference_time)

    # Print classification report
    print(f"=== Classification Report for Alpha: {alpha} ===")
    print(classification_report(y_true, y_pred, target_names=lb.classes_))
    print(f"Inference Time: {inference_time:.4f} seconds\n")
    print(f"Alpha: {alpha} - F1 Score: {f1:.4f}, Accuracy: {acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")

# Run evaluation for each alpha
for alpha in alpha_values:
    evaluate_student_with_alpha(alpha)

# Plot F1-Score vs. Alpha
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(alpha_values, f1_scores, marker='o', color='b')
plt.title("Alpha vs F1-Score")
plt.xlabel("Alpha")
plt.ylabel("F1-Score")
plt.grid(True)

# Plot Accuracy vs. Alpha
plt.subplot(2, 2, 2)
plt.plot(alpha_values, accuracies, marker='o', color='g')
plt.title("Alpha vs Accuracy")
plt.xlabel("Alpha")
plt.ylabel("Accuracy")
plt.grid(True)

# Plot Precision vs. Alpha
plt.subplot(2, 2, 3)
plt.plot(alpha_values, precisions, marker='o', color='orange')
plt.title("Alpha vs Precision")
plt.xlabel("Alpha")
plt.ylabel("Precision")
plt.grid(True)

# Plot Recall vs. Alpha
plt.subplot(2, 2, 4)
plt.plot(alpha_values, recalls, marker='o', color='red')
plt.title("Alpha vs Recall")
plt.xlabel("Alpha")
plt.ylabel("Recall")
plt.grid(True)

plt.tight_layout()
plt.show()

# Plot Inference Time vs. Alpha separately
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, inference_times, marker='o', color='purple')
plt.title("Alpha vs Inference Time")
plt.xlabel("Alpha")
plt.ylabel("Inference Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# 788/788 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step
# === Classification Report for Alpha: 0.0 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.81      0.62      0.70       142
#               airport       0.38      0.51      0.43       141
#      baseball_diamond       0.55      0.61      0.58       142
#      basketball_court       0.37      0.29      0.33       130
#                 beach       0.75      0.67      0.71       127
#                bridge       0.77      0.72      0.74       137
#             chaparral       0.81      0.91      0.86       138
#                church       0.58      0.33      0.42       135
#     circular_farmland       0.51      0.82      0.63       119
#                 cloud       0.79      0.82      0.80       137
#       commercial_area       0.39      0.58      0.46       141
#     dense_residential       0.46      0.80      0.58       138
#                desert       0.93      0.80      0.86       127
#                forest       0.73      0.90      0.80       139
#               freeway       0.49      0.48      0.48       147
#           golf_course       0.52      0.71      0.60       142
#    ground_track_field       0.55      0.54      0.55       140
#                harbor       0.82      0.76      0.79       147
#       industrial_area       0.72      0.45      0.55       141
#          intersection       0.58      0.57      0.57       154
#                island       0.86      0.88      0.87       138
#                  lake       0.80      0.89      0.84       122
#                meadow       0.77      0.88      0.82       151
#    medium_residential       0.35      0.37      0.36       115
#      mobile_home_park       0.58      0.59      0.59       151
#              mountain       0.45      0.61      0.52       138
#              overpass       0.52      0.47      0.50       129
#                palace       0.31      0.25      0.27       150
#           parking_lot       0.63      0.59      0.61       138
#               railway       0.44      0.40      0.41       144
#       railway_station       0.41      0.30      0.35       124
#  rectangular_farmland       0.35      0.40      0.37       124
#                 river       0.50      0.66      0.57       137
#            roundabout       0.33      0.35      0.34       142
#                runway       0.61      0.55      0.58       146
#               sea_ice       0.79      0.88      0.83       171
#                  ship       0.72      0.44      0.55       158
#              snowberg       0.90      0.70      0.78       135
#    sparse_residential       0.63      0.65      0.64       136
#               stadium       0.80      0.59      0.68       147
#          storage_tank       0.64      0.31      0.41       134
#          tennis_court       0.36      0.32      0.34       144
#               terrace       0.41      0.62      0.49       157
# thermal_power_station       0.52      0.33      0.40       153
#               wetland       0.69      0.39      0.50       152
#
#              accuracy                           0.58      6300
#             macro avg       0.60      0.58      0.58      6300
#          weighted avg       0.60      0.58      0.58      6300
#
# Inference Time: 5.3068 seconds
#
# Alpha: 0.0 - F1 Score: 0.5804, Accuracy: 0.5840, Precision: 0.5984, Recall: 0.5840
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step
# === Classification Report for Alpha: 0.05 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.73      0.65      0.69       142
#               airport       0.41      0.45      0.43       141
#      baseball_diamond       0.59      0.69      0.64       142
#      basketball_court       0.32      0.25      0.28       130
#                 beach       0.77      0.74      0.76       127
#                bridge       0.76      0.80      0.78       137
#             chaparral       0.93      0.89      0.91       138
#                church       0.58      0.38      0.46       135
#     circular_farmland       0.58      0.82      0.68       119
#                 cloud       0.72      0.85      0.78       137
#       commercial_area       0.49      0.41      0.45       141
#     dense_residential       0.60      0.55      0.57       138
#                desert       0.85      0.88      0.87       127
#                forest       0.76      0.88      0.82       139
#               freeway       0.46      0.52      0.48       147
#           golf_course       0.74      0.56      0.64       142
#    ground_track_field       0.55      0.61      0.58       140
#                harbor       0.77      0.78      0.78       147
#       industrial_area       0.58      0.55      0.57       141
#          intersection       0.49      0.56      0.53       154
#                island       0.88      0.88      0.88       138
#                  lake       0.80      0.90      0.85       122
#                meadow       0.86      0.81      0.83       151
#    medium_residential       0.43      0.35      0.39       115
#      mobile_home_park       0.58      0.67      0.62       151
#              mountain       0.51      0.46      0.48       138
#              overpass       0.54      0.50      0.52       129
#                palace       0.29      0.19      0.23       150
#           parking_lot       0.54      0.63      0.58       138
#               railway       0.35      0.51      0.41       144
#       railway_station       0.31      0.37      0.34       124
#  rectangular_farmland       0.41      0.48      0.44       124
#                 river       0.53      0.64      0.58       137
#            roundabout       0.44      0.42      0.43       142
#                runway       0.61      0.64      0.62       146
#               sea_ice       0.89      0.82      0.85       171
#                  ship       0.64      0.63      0.63       158
#              snowberg       0.74      0.76      0.75       135
#    sparse_residential       0.73      0.56      0.63       136
#               stadium       0.74      0.61      0.66       147
#          storage_tank       0.58      0.46      0.51       134
#          tennis_court       0.42      0.33      0.37       144
#               terrace       0.57      0.55      0.56       157
# thermal_power_station       0.40      0.45      0.42       153
#               wetland       0.58      0.55      0.56       152
#
#              accuracy                           0.60      6300
#             macro avg       0.60      0.60      0.60      6300
#          weighted avg       0.60      0.60      0.60      6300
#
# Inference Time: 5.3038 seconds
#
# Alpha: 0.05 - F1 Score: 0.5971, Accuracy: 0.5997, Precision: 0.6022, Recall: 0.5997
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step
# === Classification Report for Alpha: 0.1 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.64      0.68      0.66       142
#               airport       0.33      0.47      0.39       141
#      baseball_diamond       0.77      0.54      0.64       142
#      basketball_court       0.38      0.22      0.27       130
#                 beach       0.73      0.69      0.71       127
#                bridge       0.70      0.76      0.73       137
#             chaparral       0.94      0.91      0.92       138
#                church       0.51      0.46      0.48       135
#     circular_farmland       0.68      0.71      0.69       119
#                 cloud       0.81      0.74      0.77       137
#       commercial_area       0.36      0.45      0.40       141
#     dense_residential       0.56      0.52      0.54       138
#                desert       0.93      0.85      0.89       127
#                forest       0.85      0.88      0.86       139
#               freeway       0.43      0.46      0.44       147
#           golf_course       0.64      0.66      0.65       142
#    ground_track_field       0.65      0.59      0.61       140
#                harbor       0.73      0.80      0.76       147
#       industrial_area       0.56      0.50      0.53       141
#          intersection       0.59      0.56      0.58       154
#                island       0.79      0.93      0.85       138
#                  lake       0.78      0.89      0.83       122
#                meadow       0.80      0.90      0.84       151
#    medium_residential       0.40      0.41      0.41       115
#      mobile_home_park       0.59      0.68      0.63       151
#              mountain       0.48      0.47      0.47       138
#              overpass       0.50      0.53      0.51       129
#                palace       0.29      0.25      0.27       150
#           parking_lot       0.62      0.54      0.57       138
#               railway       0.44      0.35      0.39       144
#       railway_station       0.36      0.37      0.37       124
#  rectangular_farmland       0.45      0.53      0.49       124
#                 river       0.58      0.58      0.58       137
#            roundabout       0.42      0.35      0.38       142
#                runway       0.55      0.65      0.60       146
#               sea_ice       0.81      0.86      0.84       171
#                  ship       0.66      0.61      0.64       158
#              snowberg       0.73      0.79      0.76       135
#    sparse_residential       0.72      0.61      0.66       136
#               stadium       0.76      0.59      0.66       147
#          storage_tank       0.42      0.55      0.47       134
#          tennis_court       0.38      0.31      0.34       144
#               terrace       0.50      0.55      0.52       157
# thermal_power_station       0.43      0.39      0.41       153
#               wetland       0.57      0.60      0.58       152
#
#              accuracy                           0.59      6300
#             macro avg       0.60      0.59      0.59      6300
#          weighted avg       0.60      0.59      0.59      6300
#
# Inference Time: 10.4478 seconds
#
# Alpha: 0.1 - F1 Score: 0.5917, Accuracy: 0.5941, Precision: 0.5957, Recall: 0.5941
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step
# === Classification Report for Alpha: 0.15 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.64      0.68      0.66       142
#               airport       0.37      0.51      0.43       141
#      baseball_diamond       0.69      0.63      0.66       142
#      basketball_court       0.28      0.31      0.29       130
#                 beach       0.83      0.60      0.69       127
#                bridge       0.66      0.71      0.69       137
#             chaparral       0.93      0.90      0.91       138
#                church       0.44      0.45      0.45       135
#     circular_farmland       0.72      0.63      0.67       119
#                 cloud       0.67      0.83      0.74       137
#       commercial_area       0.35      0.48      0.41       141
#     dense_residential       0.56      0.40      0.47       138
#                desert       0.79      0.89      0.84       127
#                forest       0.83      0.89      0.86       139
#               freeway       0.54      0.44      0.49       147
#           golf_course       0.65      0.64      0.64       142
#    ground_track_field       0.62      0.41      0.50       140
#                harbor       0.84      0.71      0.77       147
#       industrial_area       0.52      0.55      0.53       141
#          intersection       0.52      0.61      0.56       154
#                island       0.90      0.83      0.86       138
#                  lake       0.82      0.81      0.82       122
#                meadow       0.86      0.85      0.86       151
#    medium_residential       0.42      0.34      0.38       115
#      mobile_home_park       0.66      0.53      0.59       151
#              mountain       0.54      0.46      0.50       138
#              overpass       0.47      0.54      0.50       129
#                palace       0.24      0.29      0.26       150
#           parking_lot       0.62      0.55      0.58       138
#               railway       0.39      0.26      0.31       144
#       railway_station       0.30      0.31      0.31       124
#  rectangular_farmland       0.42      0.64      0.51       124
#                 river       0.63      0.63      0.63       137
#            roundabout       0.34      0.38      0.36       142
#                runway       0.55      0.69      0.61       146
#               sea_ice       0.85      0.84      0.84       171
#                  ship       0.54      0.61      0.57       158
#              snowberg       0.66      0.77      0.71       135
#    sparse_residential       0.71      0.57      0.63       136
#               stadium       0.67      0.72      0.69       147
#          storage_tank       0.56      0.40      0.47       134
#          tennis_court       0.38      0.30      0.34       144
#               terrace       0.50      0.54      0.52       157
# thermal_power_station       0.42      0.37      0.39       153
#               wetland       0.57      0.61      0.59       152
#
#              accuracy                           0.58      6300
#             macro avg       0.59      0.58      0.58      6300
#          weighted avg       0.59      0.58      0.58      6300
#
# Inference Time: 10.4736 seconds
#
# Alpha: 0.15 - F1 Score: 0.5804, Accuracy: 0.5808, Precision: 0.5892, Recall: 0.5808
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step
# === Classification Report for Alpha: 0.2 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.66      0.67      0.67       142
#               airport       0.44      0.33      0.38       141
#      baseball_diamond       0.72      0.57      0.64       142
#      basketball_court       0.29      0.32      0.30       130
#                 beach       0.70      0.72      0.71       127
#                bridge       0.72      0.73      0.73       137
#             chaparral       0.95      0.87      0.91       138
#                church       0.52      0.56      0.54       135
#     circular_farmland       0.63      0.81      0.71       119
#                 cloud       0.75      0.85      0.80       137
#       commercial_area       0.49      0.40      0.44       141
#     dense_residential       0.73      0.54      0.62       138
#                desert       0.90      0.88      0.89       127
#                forest       0.85      0.86      0.85       139
#               freeway       0.38      0.56      0.45       147
#           golf_course       0.65      0.56      0.60       142
#    ground_track_field       0.58      0.44      0.50       140
#                harbor       0.84      0.69      0.76       147
#       industrial_area       0.40      0.57      0.47       141
#          intersection       0.57      0.53      0.55       154
#                island       0.79      0.92      0.85       138
#                  lake       0.72      0.86      0.78       122
#                meadow       0.82      0.85      0.84       151
#    medium_residential       0.32      0.46      0.38       115
#      mobile_home_park       0.59      0.54      0.57       151
#              mountain       0.60      0.43      0.50       138
#              overpass       0.49      0.50      0.50       129
#                palace       0.28      0.20      0.23       150
#           parking_lot       0.49      0.58      0.53       138
#               railway       0.47      0.29      0.36       144
#       railway_station       0.33      0.33      0.33       124
#  rectangular_farmland       0.45      0.46      0.45       124
#                 river       0.59      0.53      0.56       137
#            roundabout       0.38      0.30      0.33       142
#                runway       0.48      0.75      0.59       146
#               sea_ice       0.77      0.83      0.80       171
#                  ship       0.52      0.61      0.56       158
#              snowberg       0.87      0.61      0.72       135
#    sparse_residential       0.61      0.63      0.62       136
#               stadium       0.62      0.65      0.63       147
#          storage_tank       0.50      0.39      0.44       134
#          tennis_court       0.33      0.37      0.35       144
#               terrace       0.59      0.51      0.55       157
# thermal_power_station       0.45      0.45      0.45       153
#               wetland       0.54      0.57      0.56       152
#
#              accuracy                           0.58      6300
#             macro avg       0.59      0.58      0.58      6300
#          weighted avg       0.59      0.58      0.58      6300
#
# Inference Time: 5.3122 seconds
#
# Alpha: 0.2 - F1 Score: 0.5775, Accuracy: 0.5795, Precision: 0.5867, Recall: 0.5795
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step
# === Classification Report for Alpha: 0.25 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.57      0.77      0.66       142
#               airport       0.35      0.35      0.35       141
#      baseball_diamond       0.66      0.58      0.62       142
#      basketball_court       0.28      0.31      0.30       130
#                 beach       0.69      0.71      0.70       127
#                bridge       0.76      0.74      0.75       137
#             chaparral       0.95      0.77      0.85       138
#                church       0.50      0.41      0.46       135
#     circular_farmland       0.55      0.80      0.65       119
#                 cloud       0.79      0.77      0.78       137
#       commercial_area       0.43      0.35      0.39       141
#     dense_residential       0.66      0.41      0.51       138
#                desert       0.86      0.88      0.87       127
#                forest       0.90      0.76      0.82       139
#               freeway       0.47      0.45      0.46       147
#           golf_course       0.54      0.66      0.59       142
#    ground_track_field       0.63      0.48      0.54       140
#                harbor       0.79      0.73      0.76       147
#       industrial_area       0.46      0.56      0.51       141
#          intersection       0.54      0.55      0.54       154
#                island       0.83      0.90      0.86       138
#                  lake       0.77      0.80      0.79       122
#                meadow       0.85      0.83      0.84       151
#    medium_residential       0.35      0.46      0.40       115
#      mobile_home_park       0.51      0.62      0.56       151
#              mountain       0.55      0.41      0.47       138
#              overpass       0.54      0.50      0.52       129
#                palace       0.33      0.27      0.30       150
#           parking_lot       0.46      0.62      0.53       138
#               railway       0.43      0.40      0.41       144
#       railway_station       0.31      0.28      0.29       124
#  rectangular_farmland       0.38      0.59      0.46       124
#                 river       0.53      0.64      0.58       137
#            roundabout       0.48      0.32      0.38       142
#                runway       0.58      0.64      0.61       146
#               sea_ice       0.83      0.87      0.85       171
#                  ship       0.61      0.49      0.55       158
#              snowberg       0.63      0.78      0.70       135
#    sparse_residential       0.69      0.65      0.67       136
#               stadium       0.76      0.63      0.69       147
#          storage_tank       0.47      0.41      0.44       134
#          tennis_court       0.35      0.26      0.30       144
#               terrace       0.53      0.54      0.53       157
# thermal_power_station       0.44      0.41      0.43       153
#               wetland       0.52      0.63      0.57       152
#
#              accuracy                           0.58      6300
#             macro avg       0.58      0.58      0.57      6300
#          weighted avg       0.58      0.58      0.57      6300
#
# Inference Time: 5.3586 seconds
#
# Alpha: 0.25 - F1 Score: 0.5746, Accuracy: 0.5771, Precision: 0.5825, Recall: 0.5771
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step
# === Classification Report for Alpha: 0.3 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.62      0.68      0.65       142
#               airport       0.39      0.32      0.35       141
#      baseball_diamond       0.71      0.54      0.61       142
#      basketball_court       0.30      0.35      0.32       130
#                 beach       0.75      0.59      0.66       127
#                bridge       0.61      0.80      0.70       137
#             chaparral       0.90      0.82      0.86       138
#                church       0.39      0.36      0.37       135
#     circular_farmland       0.67      0.68      0.68       119
#                 cloud       0.78      0.80      0.79       137
#       commercial_area       0.34      0.43      0.38       141
#     dense_residential       0.58      0.49      0.53       138
#                desert       0.58      0.90      0.71       127
#                forest       0.81      0.84      0.83       139
#               freeway       0.34      0.55      0.42       147
#           golf_course       0.67      0.63      0.65       142
#    ground_track_field       0.61      0.51      0.56       140
#                harbor       0.75      0.78      0.77       147
#       industrial_area       0.54      0.43      0.48       141
#          intersection       0.55      0.41      0.47       154
#                island       0.83      0.86      0.85       138
#                  lake       0.76      0.81      0.78       122
#                meadow       0.84      0.81      0.82       151
#    medium_residential       0.38      0.43      0.41       115
#      mobile_home_park       0.58      0.48      0.53       151
#              mountain       0.54      0.40      0.46       138
#              overpass       0.41      0.50      0.45       129
#                palace       0.26      0.23      0.24       150
#           parking_lot       0.43      0.67      0.52       138
#               railway       0.34      0.38      0.35       144
#       railway_station       0.34      0.27      0.30       124
#  rectangular_farmland       0.46      0.49      0.47       124
#                 river       0.58      0.59      0.58       137
#            roundabout       0.36      0.31      0.33       142
#                runway       0.51      0.63      0.56       146
#               sea_ice       0.76      0.87      0.81       171
#                  ship       0.54      0.67      0.60       158
#              snowberg       0.86      0.61      0.72       135
#    sparse_residential       0.74      0.59      0.66       136
#               stadium       0.74      0.59      0.66       147
#          storage_tank       0.49      0.40      0.44       134
#          tennis_court       0.34      0.33      0.33       144
#               terrace       0.55      0.41      0.47       157
# thermal_power_station       0.44      0.35      0.39       153
#               wetland       0.50      0.55      0.52       152
#
#              accuracy                           0.56      6300
#             macro avg       0.57      0.56      0.56      6300
#          weighted avg       0.57      0.56      0.56      6300
#
# Inference Time: 6.4164 seconds
#
# Alpha: 0.3 - F1 Score: 0.5572, Accuracy: 0.5589, Precision: 0.5673, Recall: 0.5589
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step
# === Classification Report for Alpha: 0.35 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.76      0.63      0.69       142
#               airport       0.37      0.44      0.40       141
#      baseball_diamond       0.61      0.68      0.64       142
#      basketball_court       0.34      0.21      0.26       130
#                 beach       0.72      0.60      0.66       127
#                bridge       0.78      0.74      0.76       137
#             chaparral       0.90      0.90      0.90       138
#                church       0.44      0.37      0.40       135
#     circular_farmland       0.69      0.66      0.68       119
#                 cloud       0.76      0.81      0.78       137
#       commercial_area       0.41      0.40      0.41       141
#     dense_residential       0.50      0.54      0.52       138
#                desert       0.33      0.89      0.48       127
#                forest       0.49      0.88      0.63       139
#               freeway       0.52      0.45      0.48       147
#           golf_course       0.71      0.55      0.62       142
#    ground_track_field       0.62      0.50      0.56       140
#                harbor       0.83      0.70      0.76       147
#       industrial_area       0.61      0.45      0.52       141
#          intersection       0.55      0.38      0.45       154
#                island       0.83      0.86      0.85       138
#                  lake       0.82      0.77      0.79       122
#                meadow       0.82      0.83      0.82       151
#    medium_residential       0.32      0.38      0.35       115
#      mobile_home_park       0.60      0.60      0.60       151
#              mountain       0.52      0.59      0.55       138
#              overpass       0.51      0.50      0.51       129
#                palace       0.25      0.27      0.26       150
#           parking_lot       0.55      0.55      0.55       138
#               railway       0.39      0.47      0.43       144
#       railway_station       0.33      0.39      0.36       124
#  rectangular_farmland       0.44      0.52      0.48       124
#                 river       0.58      0.55      0.56       137
#            roundabout       0.42      0.25      0.31       142
#                runway       0.69      0.53      0.60       146
#               sea_ice       0.73      0.88      0.80       171
#                  ship       0.71      0.45      0.55       158
#              snowberg       0.62      0.79      0.70       135
#    sparse_residential       0.75      0.55      0.64       136
#               stadium       0.75      0.63      0.68       147
#          storage_tank       0.52      0.43      0.47       134
#          tennis_court       0.41      0.26      0.32       144
#               terrace       0.49      0.57      0.52       157
# thermal_power_station       0.37      0.35      0.36       153
#               wetland       0.57      0.57      0.57       152
#
#              accuracy                           0.56      6300
#             macro avg       0.58      0.56      0.56      6300
#          weighted avg       0.58      0.56      0.56      6300
#
# Inference Time: 4.7651 seconds
#
# Alpha: 0.35 - F1 Score: 0.5616, Accuracy: 0.5632, Precision: 0.5781, Recall: 0.5632
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
# === Classification Report for Alpha: 0.4 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.80      0.61      0.69       142
#               airport       0.40      0.39      0.40       141
#      baseball_diamond       0.52      0.66      0.58       142
#      basketball_court       0.35      0.22      0.27       130
#                 beach       0.72      0.59      0.65       127
#                bridge       0.80      0.65      0.72       137
#             chaparral       0.88      0.91      0.89       138
#                church       0.41      0.34      0.37       135
#     circular_farmland       0.70      0.63      0.66       119
#                 cloud       0.76      0.74      0.75       137
#       commercial_area       0.46      0.32      0.38       141
#     dense_residential       0.46      0.72      0.56       138
#                desert       0.38      0.89      0.53       127
#                forest       0.42      0.91      0.57       139
#               freeway       0.44      0.50      0.47       147
#           golf_course       0.63      0.51      0.57       142
#    ground_track_field       0.65      0.50      0.56       140
#                harbor       0.90      0.64      0.75       147
#       industrial_area       0.56      0.50      0.53       141
#          intersection       0.59      0.49      0.53       154
#                island       0.71      0.92      0.80       138
#                  lake       0.74      0.80      0.77       122
#                meadow       0.80      0.85      0.82       151
#    medium_residential       0.31      0.43      0.36       115
#      mobile_home_park       0.57      0.54      0.55       151
#              mountain       0.51      0.55      0.53       138
#              overpass       0.54      0.46      0.49       129
#                palace       0.34      0.21      0.26       150
#           parking_lot       0.61      0.43      0.51       138
#               railway       0.40      0.36      0.38       144
#       railway_station       0.31      0.28      0.30       124
#  rectangular_farmland       0.47      0.49      0.48       124
#                 river       0.49      0.60      0.54       137
#            roundabout       0.42      0.29      0.34       142
#                runway       0.67      0.53      0.60       146
#               sea_ice       0.45      0.91      0.60       171
#                  ship       0.74      0.41      0.52       158
#              snowberg       0.80      0.69      0.74       135
#    sparse_residential       0.63      0.55      0.59       136
#               stadium       0.81      0.57      0.67       147
#          storage_tank       0.51      0.42      0.46       134
#          tennis_court       0.34      0.31      0.32       144
#               terrace       0.50      0.46      0.48       157
# thermal_power_station       0.40      0.40      0.40       153
#               wetland       0.61      0.45      0.52       152
#
#              accuracy                           0.55      6300
#             macro avg       0.57      0.55      0.54      6300
#          weighted avg       0.57      0.55      0.54      6300
#
# Inference Time: 4.8303 seconds
#
# Alpha: 0.4 - F1 Score: 0.5441, Accuracy: 0.5483, Precision: 0.5671, Recall: 0.5483
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
# === Classification Report for Alpha: 0.45 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.74      0.58      0.65       142
#               airport       0.37      0.41      0.39       141
#      baseball_diamond       0.47      0.68      0.56       142
#      basketball_court       0.32      0.25      0.28       130
#                 beach       0.74      0.62      0.68       127
#                bridge       0.73      0.64      0.68       137
#             chaparral       0.88      0.86      0.87       138
#                church       0.43      0.33      0.38       135
#     circular_farmland       0.63      0.72      0.67       119
#                 cloud       0.73      0.81      0.77       137
#       commercial_area       0.38      0.28      0.33       141
#     dense_residential       0.57      0.55      0.56       138
#                desert       0.36      0.90      0.51       127
#                forest       0.55      0.91      0.68       139
#               freeway       0.45      0.48      0.47       147
#           golf_course       0.57      0.56      0.57       142
#    ground_track_field       0.61      0.44      0.51       140
#                harbor       0.94      0.61      0.74       147
#       industrial_area       0.59      0.43      0.50       141
#          intersection       0.52      0.50      0.51       154
#                island       0.78      0.90      0.84       138
#                  lake       0.79      0.80      0.79       122
#                meadow       0.81      0.85      0.83       151
#    medium_residential       0.31      0.44      0.37       115
#      mobile_home_park       0.56      0.50      0.53       151
#              mountain       0.50      0.43      0.46       138
#              overpass       0.54      0.40      0.46       129
#                palace       0.30      0.25      0.27       150
#           parking_lot       0.62      0.54      0.58       138
#               railway       0.46      0.31      0.37       144
#       railway_station       0.36      0.30      0.33       124
#  rectangular_farmland       0.48      0.45      0.47       124
#                 river       0.65      0.53      0.58       137
#            roundabout       0.42      0.28      0.34       142
#                runway       0.61      0.51      0.56       146
#               sea_ice       0.33      0.85      0.47       171
#                  ship       0.66      0.45      0.53       158
#              snowberg       0.78      0.73      0.76       135
#    sparse_residential       0.67      0.56      0.61       136
#               stadium       0.74      0.61      0.67       147
#          storage_tank       0.47      0.51      0.49       134
#          tennis_court       0.33      0.32      0.33       144
#               terrace       0.49      0.50      0.50       157
# thermal_power_station       0.50      0.33      0.40       153
#               wetland       0.57      0.51      0.54       152
#
#              accuracy                           0.54      6300
#             macro avg       0.56      0.54      0.54      6300
#          weighted avg       0.56      0.54      0.54      6300
#
# Inference Time: 4.9770 seconds
#
# Alpha: 0.45 - F1 Score: 0.5399, Accuracy: 0.5424, Precision: 0.5618, Recall: 0.5424
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step
# === Classification Report for Alpha: 0.5 ===
#                        precision    recall  f1-score   support
#
#              airplane       0.66      0.70      0.68       142
#               airport       0.31      0.45      0.37       141
#      baseball_diamond       0.28      0.73      0.40       142
#      basketball_court       0.36      0.21      0.26       130
#                 beach       0.66      0.60      0.63       127
#                bridge       0.65      0.66      0.66       137
#             chaparral       0.96      0.81      0.88       138
#                church       0.41      0.26      0.32       135
#     circular_farmland       0.38      0.84      0.52       119
#                 cloud       0.78      0.80      0.79       137
#       commercial_area       0.51      0.40      0.45       141
#     dense_residential       0.58      0.53      0.55       138
#                desert       0.31      0.90      0.46       127
#                forest       0.74      0.76      0.75       139
#               freeway       0.45      0.44      0.44       147
#           golf_course       0.52      0.57      0.54       142
#    ground_track_field       0.53      0.48      0.50       140
#                harbor       0.80      0.69      0.74       147
#       industrial_area       0.49      0.49      0.49       141
#          intersection       0.50      0.40      0.44       154
#                island       0.75      0.88      0.81       138
#                  lake       0.73      0.79      0.76       122
#                meadow       0.85      0.81      0.83       151
#    medium_residential       0.33      0.33      0.33       115
#      mobile_home_park       0.64      0.56      0.60       151
#              mountain       0.55      0.38      0.45       138
#              overpass       0.48      0.40      0.44       129
#                palace       0.34      0.21      0.26       150
#           parking_lot       0.56      0.55      0.55       138
#               railway       0.47      0.30      0.37       144
#       railway_station       0.36      0.27      0.31       124
#  rectangular_farmland       0.42      0.33      0.37       124
#                 river       0.60      0.44      0.51       137
#            roundabout       0.38      0.16      0.23       142
#                runway       0.57      0.55      0.56       146
#               sea_ice       0.53      0.87      0.66       171
#                  ship       0.62      0.43      0.51       158
#              snowberg       0.81      0.64      0.72       135
#    sparse_residential       0.74      0.51      0.61       136
#               stadium       0.76      0.58      0.66       147
#          storage_tank       0.42      0.42      0.42       134
#          tennis_court       0.43      0.24      0.31       144
#               terrace       0.46      0.54      0.50       157
# thermal_power_station       0.46      0.29      0.36       153
#               wetland       0.51      0.61      0.55       152
#
#              accuracy                           0.53      6300
#             macro avg       0.55      0.53      0.52      6300
#          weighted avg       0.55      0.53      0.52      6300
#
# Inference Time: 5.3245 seconds
#
# Alpha: 0.5 - F1 Score: 0.5245, Accuracy: 0.5294, Precision: 0.5502, Recall: 0.5294
