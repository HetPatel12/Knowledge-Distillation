# %%
# Install the required libraries
# !pip install opendatasets --upgrade --quiet
# !pip install kaggle --quiet

# Import Kaggle and OpenDatasets to download datasets from Kaggle
import opendatasets as od

# Download the dataset from Kaggle
dataset_url = 'https://www.kaggle.com/datasets/abdulhasibuddin/uc-merced-land-use-dataset'
od.download(dataset_url)

import os
import random
import cv2
import numpy as np
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.models import Model
import tensorflow as tf

# Set the path to the image folder
data_path = 'uc-merced-land-use-dataset/UCMerced_LandUse/Images'

# Initialize image data and labels
image_data = []
labels = []

# Load the image dataset
for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(".tif"):
            # Read the image
            image = cv2.imread(os.path.join(root, file))
            image = cv2.resize(image, (128, 128))
            image = img_to_array(image)
            image_data.append(image)

            # Use the folder name as the label
            label = root.split(os.path.sep)[-1]
            labels.append(label)

# Convert to numpy arrays and normalize the images
image_data = np.array(image_data, dtype="float") / 255.0
labels = np.array(labels)

# Binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size=0.2, random_state=42)

print(f'Training samples: {len(x_train)}, Testing samples: {len(x_test)}')

# Define the teacher model (more layers)
def teacher_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Define the student model (fewer layers)
def student_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

input_shape = (128, 128, 3)
num_classes = len(lb.classes_)

# Build teacher and student models
teacher = teacher_model(input_shape, num_classes)
student = student_model(input_shape, num_classes)

# Define a learning rate scheduler function
# def lr_scheduler(epoch, lr):
#     return lr * tf.math.exp(-0.1) if epoch >= 10 else lr

def lr_scheduler(epoch, lr):
    return float(lr * tf.math.exp(-0.1)) if epoch >= 10 else float(lr)

# Compile and train the teacher model
teacher.compile(optimizer=SGD(learning_rate=1e-2, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
teacher.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Precompute teacher's predictions for distillation
teacher_preds = teacher.predict(x_train)

# Define distillation loss function
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true = tf.keras.activations.softmax(y_true / temperature)
    y_pred = tf.keras.activations.softmax(y_pred / temperature)
    teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return alpha * soft_loss + (1. - alpha) * hard_loss

# Evaluate models
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
#student_score = student.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
#print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: akshayanand2002
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/abdulhasibuddin/uc-merced-land-use-dataset
# Downloading uc-merced-land-use-dataset.zip to ./uc-merced-land-use-dataset
# 100%|██████████| 317M/317M [00:04<00:00, 70.7MB/s]
# Training samples: 1680, Testing samples: 420
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 249s 5s/step - accuracy: 0.0506 - loss: 3.0448 - val_accuracy: 0.0357 - val_loss: 3.0246 - learning_rate: 0.0100
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 270s 5s/step - accuracy: 0.0688 - loss: 2.9808 - val_accuracy: 0.1381 - val_loss: 2.8650 - learning_rate: 0.0100
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 256s 5s/step - accuracy: 0.1817 - loss: 2.7241 - val_accuracy: 0.1071 - val_loss: 2.6980 - learning_rate: 0.0100
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 266s 5s/step - accuracy: 0.1932 - loss: 2.5424 - val_accuracy: 0.2690 - val_loss: 2.3397 - learning_rate: 0.0100
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 260s 5s/step - accuracy: 0.3305 - loss: 2.2003 - val_accuracy: 0.2976 - val_loss: 2.2229 - learning_rate: 0.0100
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 248s 5s/step - accuracy: 0.3284 - loss: 2.0853 - val_accuracy: 0.3476 - val_loss: 1.9744 - learning_rate: 0.0100
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 268s 5s/step - accuracy: 0.4172 - loss: 1.8528 - val_accuracy: 0.4476 - val_loss: 1.7033 - learning_rate: 0.0100
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 256s 5s/step - accuracy: 0.4926 - loss: 1.6030 - val_accuracy: 0.4405 - val_loss: 1.7249 - learning_rate: 0.0100
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 266s 5s/step - accuracy: 0.5551 - loss: 1.3607 - val_accuracy: 0.4833 - val_loss: 1.6654 - learning_rate: 0.0100
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 258s 5s/step - accuracy: 0.6136 - loss: 1.2299 - val_accuracy: 0.4762 - val_loss: 1.5674 - learning_rate: 0.0100
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 251s 5s/step - accuracy: 0.7258 - loss: 0.8941 - val_accuracy: 0.5167 - val_loss: 1.5234 - learning_rate: 0.0090
# Epoch 12/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 260s 5s/step - accuracy: 0.7853 - loss: 0.6694 - val_accuracy: 0.5905 - val_loss: 1.3863 - learning_rate: 0.0082
# Epoch 13/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 262s 5s/step - accuracy: 0.8588 - loss: 0.4562 - val_accuracy: 0.6000 - val_loss: 1.5115 - learning_rate: 0.0074
# Epoch 14/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 261s 5s/step - accuracy: 0.8560 - loss: 0.4805 - val_accuracy: 0.6333 - val_loss: 1.3887 - learning_rate: 0.0067
# Epoch 15/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 262s 5s/step - accuracy: 0.9106 - loss: 0.2690 - val_accuracy: 0.6357 - val_loss: 1.4051 - learning_rate: 0.0061
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step
# Teacher test accuracy: 63.57%

# %%
# Define distillation loss function
def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=0.1):
    teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
    y_true = tf.keras.activations.softmax(y_true / temperature)
    y_pred = tf.keras.activations.softmax(y_pred / temperature)
    teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
    soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
    hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return alpha * soft_loss + (1. - alpha) * hard_loss

# Compile and train the student model using distillation loss
student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds), metrics=['accuracy'])
student.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test), callbacks=[LearningRateScheduler(lr_scheduler)])

# Evaluate models
teacher_score = teacher.evaluate(x_test, y_test, verbose=0)
student_score = student.evaluate(x_test, y_test, verbose=0)
print(f'Teacher test accuracy: {teacher_score[1] * 100:.2f}%')
print(f'Student test accuracy: {student_score[1] * 100:.2f}%')
# Out:
# Epoch 1/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.0437 - loss: 3.0445 - val_accuracy: 0.0905 - val_loss: 3.0445 - learning_rate: 0.0010
# Epoch 2/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.1142 - loss: 3.0445 - val_accuracy: 0.1571 - val_loss: 3.0444 - learning_rate: 0.0010
# Epoch 3/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.1925 - loss: 3.0444 - val_accuracy: 0.1952 - val_loss: 3.0442 - learning_rate: 0.0010
# Epoch 4/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.2739 - loss: 3.0442 - val_accuracy: 0.2476 - val_loss: 3.0442 - learning_rate: 0.0010
# Epoch 5/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.3492 - loss: 3.0441 - val_accuracy: 0.3405 - val_loss: 3.0440 - learning_rate: 0.0010
# Epoch 6/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.4352 - loss: 3.0438 - val_accuracy: 0.4286 - val_loss: 3.0439 - learning_rate: 0.0010
# Epoch 7/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.5256 - loss: 3.0436 - val_accuracy: 0.3786 - val_loss: 3.0439 - learning_rate: 0.0010
# Epoch 8/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5774 - loss: 3.0434 - val_accuracy: 0.4524 - val_loss: 3.0437 - learning_rate: 0.0010
# Epoch 9/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6355 - loss: 3.0433 - val_accuracy: 0.5286 - val_loss: 3.0435 - learning_rate: 0.0010
# Epoch 10/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7213 - loss: 3.0430 - val_accuracy: 0.5429 - val_loss: 3.0436 - learning_rate: 0.0010
# Epoch 11/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7816 - loss: 3.0428 - val_accuracy: 0.5452 - val_loss: 3.0436 - learning_rate: 9.0484e-04
# Epoch 12/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7919 - loss: 3.0428 - val_accuracy: 0.5786 - val_loss: 3.0434 - learning_rate: 8.1873e-04
# Epoch 13/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8419 - loss: 3.0426 - val_accuracy: 0.5905 - val_loss: 3.0434 - learning_rate: 7.4082e-04
# Epoch 14/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8755 - loss: 3.0425 - val_accuracy: 0.6214 - val_loss: 3.0433 - learning_rate: 6.7032e-04
# Epoch 15/15
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9075 - loss: 3.0424 - val_accuracy: 0.6500 - val_loss: 3.0433 - learning_rate: 6.0653e-04
# Teacher test accuracy: 63.57%
# Student test accuracy: 65.00%

# %%
# Evaluate and print additional metrics for teacher and student models
from sklearn.metrics import classification_report
import time

def evaluate_model(model, x_test, y_test):
    # Predict the labels
    start_time = time.time()
    y_pred_probs = model.predict(x_test)
    inference_time = time.time() - start_time

    # Get the predicted classes
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate precision, recall, F1 score
    report = classification_report(y_true, y_pred, target_names=lb.classes_)

    # Print the metrics
    print(report)
    print(f"Inference Time: {inference_time:.4f} seconds")
    return y_pred_probs

print("=== Teacher Model Evaluation ===")
teacher_pred_probs = evaluate_model(teacher, x_test, y_test)

print("\n=== Student Model Evaluation ===")
student_pred_probs = evaluate_model(student, x_test, y_test)
# Out:
# === Teacher Model Evaluation ===
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step
#                    precision    recall  f1-score   support
#
#      agricultural       0.56      0.83      0.67        23
#          airplane       0.67      0.70      0.68        20
#   baseballdiamond       0.79      0.68      0.73        22
#             beach       1.00      0.39      0.56        18
#         buildings       0.26      0.41      0.32        17
#         chaparral       0.72      0.93      0.81        14
#  denseresidential       0.48      0.78      0.60        18
#            forest       0.88      0.83      0.86        18
#           freeway       0.62      0.62      0.62        21
#        golfcourse       0.71      0.65      0.68        26
#            harbor       0.81      0.92      0.86        24
#      intersection       0.57      0.72      0.63        18
# mediumresidential       0.53      0.33      0.41        27
#    mobilehomepark       0.69      0.65      0.67        17
#          overpass       0.57      0.47      0.52        17
#        parkinglot       0.86      0.80      0.83        15
#             river       0.65      0.85      0.73        26
#            runway       0.87      0.81      0.84        16
# sparseresidential       0.58      0.61      0.60        23
#      storagetanks       0.33      0.15      0.21        20
#       tenniscourt       0.60      0.30      0.40        20
#
#          accuracy                           0.64       420
#         macro avg       0.65      0.64      0.63       420
#      weighted avg       0.65      0.64      0.63       420
#
# Inference Time: 41.1370 seconds
#
# === Student Model Evaluation ===
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step
#                    precision    recall  f1-score   support
#
#      agricultural       0.69      0.78      0.73        23
#          airplane       0.56      0.45      0.50        20
#   baseballdiamond       0.90      0.82      0.86        22
#             beach       1.00      1.00      1.00        18
#         buildings       0.36      0.29      0.32        17
#         chaparral       0.74      1.00      0.85        14
#  denseresidential       0.38      0.28      0.32        18
#            forest       0.62      0.89      0.73        18
#           freeway       0.64      0.67      0.65        21
#        golfcourse       0.86      0.46      0.60        26
#            harbor       0.80      1.00      0.89        24
#      intersection       0.65      0.72      0.68        18
# mediumresidential       0.41      0.44      0.43        27
#    mobilehomepark       0.73      0.47      0.57        17
#          overpass       0.58      0.65      0.61        17
#        parkinglot       0.90      0.60      0.72        15
#             river       0.54      0.77      0.63        26
#            runway       0.88      0.94      0.91        16
# sparseresidential       0.72      0.78      0.75        23
#      storagetanks       0.33      0.30      0.32        20
#       tenniscourt       0.50      0.40      0.44        20
#
#          accuracy                           0.65       420
#         macro avg       0.66      0.65      0.64       420
#      weighted avg       0.65      0.65      0.64       420
#
# Inference Time: 4.2618 seconds

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import time

# Define alpha values for experiments
alpha_values = [0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
f1_scores = []
accuracies = []
precisions = []
recalls = []
inference_times = []

# Function to evaluate F1-score, accuracy, precision, recall, and inference time for a given model and alpha
def evaluate_student_with_alpha(alpha):
    # Redefine distillation loss function with current alpha
    def distillation_loss(y_true, y_pred, teacher_preds, temperature=3.0, alpha=alpha):
        teacher_batch_preds = tf.gather(teacher_preds, tf.range(tf.shape(y_pred)[0]))
        y_true = tf.keras.activations.softmax(y_true / temperature)
        y_pred = tf.keras.activations.softmax(y_pred / temperature)
        teacher_batch_preds = tf.keras.activations.softmax(teacher_batch_preds / temperature)
        soft_loss = tf.keras.losses.categorical_crossentropy(teacher_batch_preds, y_pred)
        hard_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return alpha * soft_loss + (1. - alpha) * hard_loss

    # Compile the student model with the new distillation loss
    student.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                    loss=lambda y_true, y_pred: distillation_loss(y_true, y_pred, teacher_preds),
                    metrics=['accuracy'])

    # Train the student model
    student.fit(x_train, y_train, batch_size=32, epochs=15, validation_data=(x_test, y_test),
                callbacks=[LearningRateScheduler(lr_scheduler)], verbose=0)

    # Predict and evaluate
    start_time = time.time()
    y_pred_probs = student.predict(x_test)
    inference_time = time.time() - start_time
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Calculate and store F1-score, accuracy, precision, recall, and inference time
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')

    # Append the results
    f1_scores.append(f1)
    accuracies.append(acc)
    precisions.append(precision)
    recalls.append(recall)
    inference_times.append(inference_time)

    # Print classification report
    print(f"=== Classification Report for Alpha: {alpha} ===")
    print(classification_report(y_true, y_pred, target_names=lb.classes_))
    print(f"Inference Time: {inference_time:.4f} seconds\n")
    print(f"Alpha: {alpha} - F1 Score: {f1:.4f}, Accuracy: {acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")

# Run evaluation for each alpha
for alpha in alpha_values:
    evaluate_student_with_alpha(alpha)

# Plot F1-Score vs. Alpha
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(alpha_values, f1_scores, marker='o', color='b')
plt.title("Alpha vs F1-Score")
plt.xlabel("Alpha")
plt.ylabel("F1-Score")
plt.grid(True)

# Plot Accuracy vs. Alpha
plt.subplot(2, 2, 2)
plt.plot(alpha_values, accuracies, marker='o', color='g')
plt.title("Alpha vs Accuracy")
plt.xlabel("Alpha")
plt.ylabel("Accuracy")
plt.grid(True)

# Plot Precision vs. Alpha
plt.subplot(2, 2, 3)
plt.plot(alpha_values, precisions, marker='o', color='orange')
plt.title("Alpha vs Precision")
plt.xlabel("Alpha")
plt.ylabel("Precision")
plt.grid(True)

# Plot Recall vs. Alpha
plt.subplot(2, 2, 4)
plt.plot(alpha_values, recalls, marker='o', color='red')
plt.title("Alpha vs Recall")
plt.xlabel("Alpha")
plt.ylabel("Recall")
plt.grid(True)

plt.tight_layout()
plt.show()

# Plot Inference Time vs. Alpha separately
plt.figure(figsize=(7, 5))
plt.plot(alpha_values, inference_times, marker='o', color='purple')
plt.title("Alpha vs Inference Time")
plt.xlabel("Alpha")
plt.ylabel("Inference Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step
# === Classification Report for Alpha: 0.0 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.69      0.96      0.80        23
#          airplane       0.90      0.45      0.60        20
#   baseballdiamond       0.86      0.82      0.84        22
#             beach       1.00      0.94      0.97        18
#         buildings       0.33      0.24      0.28        17
#         chaparral       0.82      1.00      0.90        14
#  denseresidential       0.33      0.50      0.40        18
#            forest       0.71      0.94      0.81        18
#           freeway       0.72      0.62      0.67        21
#        golfcourse       0.65      0.42      0.51        26
#            harbor       0.77      1.00      0.87        24
#      intersection       0.56      0.78      0.65        18
# mediumresidential       0.46      0.41      0.43        27
#    mobilehomepark       0.47      0.41      0.44        17
#          overpass       0.67      0.47      0.55        17
#        parkinglot       0.67      0.93      0.78        15
#             river       0.84      0.81      0.82        26
#            runway       0.83      0.94      0.88        16
# sparseresidential       0.68      0.83      0.75        23
#      storagetanks       0.50      0.25      0.33        20
#       tenniscourt       0.44      0.35      0.39        20
#
#          accuracy                           0.66       420
#         macro avg       0.66      0.67      0.65       420
#      weighted avg       0.66      0.66      0.65       420
#
# Inference Time: 5.3106 seconds
#
# Alpha: 0.0 - F1 Score: 0.6491, Accuracy: 0.6643, Precision: 0.6629, Recall: 0.6643
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step
# === Classification Report for Alpha: 0.05 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.78      0.91      0.84        23
#          airplane       0.52      0.60      0.56        20
#   baseballdiamond       0.85      0.77      0.81        22
#             beach       0.95      1.00      0.97        18
#         buildings       0.35      0.41      0.38        17
#         chaparral       0.78      1.00      0.88        14
#  denseresidential       0.28      0.44      0.34        18
#            forest       0.94      0.94      0.94        18
#           freeway       0.83      0.48      0.61        21
#        golfcourse       0.56      0.58      0.57        26
#            harbor       0.88      0.92      0.90        24
#      intersection       0.74      0.78      0.76        18
# mediumresidential       0.35      0.26      0.30        27
#    mobilehomepark       0.54      0.41      0.47        17
#          overpass       0.53      0.59      0.56        17
#        parkinglot       0.83      1.00      0.91        15
#             river       0.79      0.85      0.81        26
#            runway       0.88      0.94      0.91        16
# sparseresidential       0.75      0.65      0.70        23
#      storagetanks       0.21      0.15      0.18        20
#       tenniscourt       0.36      0.25      0.29        20
#
#          accuracy                           0.65       420
#         macro avg       0.65      0.66      0.65       420
#      weighted avg       0.65      0.65      0.64       420
#
# Inference Time: 4.4132 seconds
#
# Alpha: 0.05 - F1 Score: 0.6440, Accuracy: 0.6524, Precision: 0.6488, Recall: 0.6524
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step
# === Classification Report for Alpha: 0.1 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.88      0.96      0.92        23
#          airplane       0.59      0.50      0.54        20
#   baseballdiamond       0.83      0.86      0.84        22
#             beach       0.95      1.00      0.97        18
#         buildings       0.25      0.53      0.34        17
#         chaparral       0.82      1.00      0.90        14
#  denseresidential       0.35      0.33      0.34        18
#            forest       0.85      0.94      0.89        18
#           freeway       0.74      0.67      0.70        21
#        golfcourse       0.62      0.19      0.29        26
#            harbor       0.82      0.96      0.88        24
#      intersection       0.67      0.67      0.67        18
# mediumresidential       0.50      0.26      0.34        27
#    mobilehomepark       0.40      0.59      0.48        17
#          overpass       0.45      0.53      0.49        17
#        parkinglot       0.72      0.87      0.79        15
#             river       0.83      0.77      0.80        26
#            runway       0.71      0.94      0.81        16
# sparseresidential       0.68      0.65      0.67        23
#      storagetanks       0.20      0.10      0.13        20
#       tenniscourt       0.47      0.45      0.46        20
#
#          accuracy                           0.64       420
#         macro avg       0.64      0.66      0.63       420
#      weighted avg       0.64      0.64      0.63       420
#
# Inference Time: 4.3265 seconds
#
# Alpha: 0.1 - F1 Score: 0.6254, Accuracy: 0.6405, Precision: 0.6408, Recall: 0.6405
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 421ms/step
# === Classification Report for Alpha: 0.15 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.85      0.96      0.90        23
#          airplane       0.52      0.60      0.56        20
#   baseballdiamond       0.85      0.77      0.81        22
#             beach       1.00      0.94      0.97        18
#         buildings       0.47      0.47      0.47        17
#         chaparral       0.78      1.00      0.88        14
#  denseresidential       0.37      0.39      0.38        18
#            forest       0.85      0.94      0.89        18
#           freeway       0.56      0.48      0.51        21
#        golfcourse       0.56      0.19      0.29        26
#            harbor       0.88      0.92      0.90        24
#      intersection       0.70      0.78      0.74        18
# mediumresidential       0.43      0.37      0.40        27
#    mobilehomepark       0.41      0.41      0.41        17
#          overpass       0.56      0.53      0.55        17
#        parkinglot       0.76      0.87      0.81        15
#             river       0.67      0.77      0.71        26
#            runway       0.80      1.00      0.89        16
# sparseresidential       0.67      0.52      0.59        23
#      storagetanks       0.22      0.10      0.14        20
#       tenniscourt       0.29      0.55      0.38        20
#
#          accuracy                           0.63       420
#         macro avg       0.63      0.65      0.63       420
#      weighted avg       0.63      0.63      0.62       420
#
# Inference Time: 6.0779 seconds
#
# Alpha: 0.15 - F1 Score: 0.6170, Accuracy: 0.6310, Precision: 0.6255, Recall: 0.6310
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 386ms/step
# === Classification Report for Alpha: 0.2 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.76      0.96      0.85        23
#          airplane       0.48      0.65      0.55        20
#   baseballdiamond       0.82      0.82      0.82        22
#             beach       1.00      1.00      1.00        18
#         buildings       0.33      0.41      0.37        17
#         chaparral       0.88      1.00      0.93        14
#  denseresidential       0.38      0.33      0.35        18
#            forest       0.85      0.94      0.89        18
#           freeway       0.62      0.62      0.62        21
#        golfcourse       0.48      0.42      0.45        26
#            harbor       0.84      0.88      0.86        24
#      intersection       0.78      0.78      0.78        18
# mediumresidential       0.52      0.48      0.50        27
#    mobilehomepark       0.38      0.59      0.47        17
#          overpass       0.53      0.53      0.53        17
#        parkinglot       0.76      0.87      0.81        15
#             river       0.87      0.77      0.82        26
#            runway       0.79      0.94      0.86        16
# sparseresidential       0.75      0.52      0.62        23
#      storagetanks       0.15      0.10      0.12        20
#       tenniscourt       0.62      0.25      0.36        20
#
#          accuracy                           0.65       420
#         macro avg       0.65      0.66      0.64       420
#      weighted avg       0.65      0.65      0.64       420
#
# Inference Time: 5.9689 seconds
#
# Alpha: 0.2 - F1 Score: 0.6400, Accuracy: 0.6500, Precision: 0.6470, Recall: 0.6500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step
# === Classification Report for Alpha: 0.25 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.67      0.96      0.79        23
#          airplane       0.52      0.55      0.54        20
#   baseballdiamond       0.89      0.73      0.80        22
#             beach       1.00      1.00      1.00        18
#         buildings       0.44      0.65      0.52        17
#         chaparral       0.93      1.00      0.97        14
#  denseresidential       0.53      0.50      0.51        18
#            forest       0.74      0.94      0.83        18
#           freeway       0.81      0.62      0.70        21
#        golfcourse       0.58      0.42      0.49        26
#            harbor       0.88      0.92      0.90        24
#      intersection       0.50      0.83      0.62        18
# mediumresidential       0.50      0.30      0.37        27
#    mobilehomepark       0.50      0.53      0.51        17
#          overpass       0.50      0.71      0.59        17
#        parkinglot       0.65      0.87      0.74        15
#             river       0.86      0.73      0.79        26
#            runway       0.79      0.94      0.86        16
# sparseresidential       0.65      0.57      0.60        23
#      storagetanks       0.27      0.15      0.19        20
#       tenniscourt       0.60      0.30      0.40        20
#
#          accuracy                           0.66       420
#         macro avg       0.66      0.68      0.65       420
#      weighted avg       0.66      0.66      0.65       420
#
# Inference Time: 4.3324 seconds
#
# Alpha: 0.25 - F1 Score: 0.6458, Accuracy: 0.6595, Precision: 0.6589, Recall: 0.6595
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 288ms/step
# === Classification Report for Alpha: 0.3 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.69      0.96      0.80        23
#          airplane       0.73      0.55      0.63        20
#   baseballdiamond       0.71      0.77      0.74        22
#             beach       1.00      0.94      0.97        18
#         buildings       0.44      0.41      0.42        17
#         chaparral       0.82      1.00      0.90        14
#  denseresidential       0.35      0.50      0.41        18
#            forest       0.94      0.83      0.88        18
#           freeway       0.92      0.52      0.67        21
#        golfcourse       0.71      0.38      0.50        26
#            harbor       0.88      0.92      0.90        24
#      intersection       0.48      0.83      0.61        18
# mediumresidential       0.78      0.26      0.39        27
#    mobilehomepark       0.73      0.47      0.57        17
#          overpass       0.23      0.71      0.35        17
#        parkinglot       0.93      0.93      0.93        15
#             river       0.86      0.73      0.79        26
#            runway       0.58      0.94      0.71        16
# sparseresidential       0.76      0.57      0.65        23
#      storagetanks       0.25      0.20      0.22        20
#       tenniscourt       0.71      0.25      0.37        20
#
#          accuracy                           0.64       420
#         macro avg       0.69      0.65      0.64       420
#      weighted avg       0.70      0.64      0.63       420
#
# Inference Time: 5.3230 seconds
#
# Alpha: 0.3 - F1 Score: 0.6341, Accuracy: 0.6357, Precision: 0.6991, Recall: 0.6357
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 408ms/step
# === Classification Report for Alpha: 0.35 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.84      0.91      0.88        23
#          airplane       0.69      0.45      0.55        20
#   baseballdiamond       0.82      0.82      0.82        22
#             beach       1.00      0.89      0.94        18
#         buildings       0.40      0.47      0.43        17
#         chaparral       0.88      1.00      0.93        14
#  denseresidential       0.36      0.56      0.43        18
#            forest       0.94      0.94      0.94        18
#           freeway       1.00      0.38      0.55        21
#        golfcourse       0.89      0.31      0.46        26
#            harbor       0.96      0.92      0.94        24
#      intersection       0.39      0.83      0.54        18
# mediumresidential       0.83      0.19      0.30        27
#    mobilehomepark       0.80      0.47      0.59        17
#          overpass       0.20      0.76      0.32        17
#        parkinglot       1.00      0.80      0.89        15
#             river       0.94      0.65      0.77        26
#            runway       0.60      0.94      0.73        16
# sparseresidential       0.81      0.57      0.67        23
#      storagetanks       0.18      0.20      0.19        20
#       tenniscourt       0.64      0.35      0.45        20
#
#          accuracy                           0.62       420
#         macro avg       0.72      0.64      0.63       420
#      weighted avg       0.74      0.62      0.63       420
#
# Inference Time: 10.5382 seconds
#
# Alpha: 0.35 - F1 Score: 0.6281, Accuracy: 0.6190, Precision: 0.7371, Recall: 0.6190
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 287ms/step
# === Classification Report for Alpha: 0.4 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.79      0.96      0.86        23
#          airplane       0.73      0.55      0.63        20
#   baseballdiamond       0.83      0.86      0.84        22
#             beach       1.00      0.94      0.97        18
#         buildings       0.43      0.35      0.39        17
#         chaparral       0.93      1.00      0.97        14
#  denseresidential       0.39      0.50      0.44        18
#            forest       1.00      0.83      0.91        18
#           freeway       1.00      0.33      0.50        21
#        golfcourse       0.63      0.46      0.53        26
#            harbor       0.96      0.92      0.94        24
#      intersection       0.35      0.83      0.49        18
# mediumresidential       0.75      0.22      0.34        27
#    mobilehomepark       1.00      0.29      0.45        17
#          overpass       0.23      0.88      0.37        17
#        parkinglot       1.00      0.73      0.85        15
#             river       0.94      0.58      0.71        26
#            runway       0.58      0.94      0.71        16
# sparseresidential       0.81      0.57      0.67        23
#      storagetanks       0.24      0.30      0.27        20
#       tenniscourt       0.71      0.25      0.37        20
#
#          accuracy                           0.62       420
#         macro avg       0.73      0.63      0.63       420
#      weighted avg       0.73      0.62      0.63       420
#
# Inference Time: 4.3807 seconds
#
# Alpha: 0.4 - F1 Score: 0.6252, Accuracy: 0.6190, Precision: 0.7347, Recall: 0.6190
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 290ms/step
# === Classification Report for Alpha: 0.45 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.85      0.96      0.90        23
#          airplane       0.75      0.60      0.67        20
#   baseballdiamond       0.79      0.86      0.83        22
#             beach       1.00      1.00      1.00        18
#         buildings       0.37      0.41      0.39        17
#         chaparral       0.93      1.00      0.97        14
#  denseresidential       0.36      0.50      0.42        18
#            forest       0.94      0.89      0.91        18
#           freeway       1.00      0.43      0.60        21
#        golfcourse       0.82      0.35      0.49        26
#            harbor       0.96      0.96      0.96        24
#      intersection       0.33      0.89      0.48        18
# mediumresidential       0.83      0.19      0.30        27
#    mobilehomepark       1.00      0.53      0.69        17
#          overpass       0.24      0.82      0.37        17
#        parkinglot       1.00      0.87      0.93        15
#             river       1.00      0.62      0.76        26
#            runway       0.58      0.94      0.71        16
# sparseresidential       0.80      0.52      0.63        23
#      storagetanks       0.32      0.30      0.31        20
#       tenniscourt       0.75      0.15      0.25        20
#
#          accuracy                           0.64       420
#         macro avg       0.74      0.66      0.65       420
#      weighted avg       0.76      0.64      0.64       420
#
# Inference Time: 5.3304 seconds
#
# Alpha: 0.45 - F1 Score: 0.6385, Accuracy: 0.6357, Precision: 0.7554, Recall: 0.6357
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 289ms/step
# === Classification Report for Alpha: 0.5 ===
#                    precision    recall  f1-score   support
#
#      agricultural       0.81      0.96      0.88        23
#          airplane       0.77      0.50      0.61        20
#   baseballdiamond       0.78      0.82      0.80        22
#             beach       1.00      0.94      0.97        18
#         buildings       0.38      0.47      0.42        17
#         chaparral       0.93      1.00      0.97        14
#  denseresidential       0.31      0.50      0.38        18
#            forest       0.89      0.94      0.92        18
#           freeway       0.91      0.48      0.62        21
#        golfcourse       0.80      0.31      0.44        26
#            harbor       0.92      0.96      0.94        24
#      intersection       0.29      0.83      0.43        18
# mediumresidential       0.80      0.15      0.25        27
#    mobilehomepark       0.90      0.53      0.67        17
#          overpass       0.21      0.71      0.32        17
#        parkinglot       1.00      0.80      0.89        15
#             river       1.00      0.62      0.76        26
#            runway       0.79      0.94      0.86        16
# sparseresidential       0.67      0.52      0.59        23
#      storagetanks       0.27      0.20      0.23        20
#       tenniscourt       0.67      0.20      0.31        20
#
#          accuracy                           0.62       420
#         macro avg       0.72      0.64      0.63       420
#      weighted avg       0.73      0.62      0.62       420
#
# Inference Time: 5.3289 seconds
#
# Alpha: 0.5 - F1 Score: 0.6217, Accuracy: 0.6167, Precision: 0.7282, Recall: 0.6167
